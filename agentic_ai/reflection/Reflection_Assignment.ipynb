# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %%
import unittests

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str: 
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""You are best essay writer. Draft an essay about {topic}. Cover 3 points majorly \n
     - It's advantages \n
     - It's disadvantages \n
     - It's effect on socity""" 

    ### END CODE HERE ###
    
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %% [markdown]
# Run the following cell to check your code is working correctly:

# %%
# Test your code!
unittests.test_generate_draft(generate_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:o4-mini"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""Assume you are the best critic to review essay's. review following draft version \n
    with structure, clarity, strength of argument, and writing style. \n
    and provide you response if you see improvement draft: {draft}"""

    ### END CODE HERE ###

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_reflect_on_draft(reflect_on_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f""" Check the revised essay here for improve clarity, coherence, argument strength, and overall flow with it's draft version \n
    cross check the date and event mentioned in revise version by web serach \n
    draft: {original_draft}
    revised/revied version: {reflection}""" 

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_revise_draft(revise_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.
#
# Observe the outputs of each step. You do **not** need to modify the outputs — just verify that the workflow runs as expected and each component returns a valid string.

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

# Agent 1 – Draft
draft = generate_draft(essay_prompt)
print("📝 Draft:\n")
print(draft)

# Agent 2 – Reflection
feedback = reflect_on_draft(draft)
print("\n🧠 Feedback:\n")
print(feedback)

# Agent 3 – Revision
revised = revise_draft(draft, feedback)
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# **Title: Should Social Media Platforms Be Regulated by the Government?**
#
# In recent years, social media platforms have become central to communication, information dissemination, and social interaction worldwide. The rise in their influence has sparked an ongoing debate regarding whether these platforms should be regulated by the government. While there are compelling arguments on both sides, understanding the potential advantages and disadvantages, as well as the broader effects on society, is crucial to forming a well-rounded perspective.
#
# **Advantages of Government Regulation**
#
# One of the primary advantages of government regulation of social media platforms is the promise of increased accountability and transparency. With regulation, there is potential for the establishment of clear guidelines and standards that platforms must adhere to. This can help combat misinformation and fake news by holding platforms accountable for the content they allow to circulate. Furthermore, government regulation can ensure that users' data is protected, establishing legal frameworks to prevent unauthorized data collection and usage, which is critical in an age where personal data is as valuable as currency.
#
# Additionally, regulation can aid in the protection of vulnerable groups from harmful and abusive content. By implementing stricter controls and monitoring systems, governments can ensure that platforms actively work to prevent hate speech, cyberbullying, and other harmful behaviors, creating safer online environments for all users. This, in turn, can contribute to healthier digital social interactions and greater trust in these digital platforms.
#
# **Disadvantages of Government Regulation**
#
# Despite the potential benefits, there are significant concerns regarding government regulation of social media platforms. One major disadvantage is the risk of censorship and infringement on free speech. Government involvement in regulating content may lead to the suppression of dissenting opinions and the curtailment of freedom of expression, depending on how regulation is implemented. This can be particularly concerning in countries where governments have a history of oppressive measures against political opponents and journalists.
#
# Moreover, the potential for regulatory overreach is significant. Given the complexity and rapid evolution of technology and digital communication, there is a risk that government regulations might not only be slow to adapt but also stifle innovation. Platforms may be burdened with compliance requirements, reducing their agility and capacity to innovate and respond to the needs of their users dynamically.
#
# **Effect on Society**
#
# The regulation of social media platforms has a profound impact on society, both in its promise to mitigate harm and the potential to alter the fabric of free discourse. On one hand, effective regulation can enhance civic discourse by curbing the spread of misinformation and creating spaces where healthy debate can thrive. On the other hand, if not carefully crafted, regulation can hinder the very discourse it aims to protect, leading to homogenization of viewpoints and diminished public dialogue.
#
# Social media platforms, in their current unregulated or self-regulated states, have already shown the capability to dramatically sway public opinion and influence social and political movements. The introduction of government regulation, therefore, places further emphasis on the responsibility of both governments and platform providers to balance the need for security with the preservation of democratic freedoms.
#
# **Conclusion**
#
# The question of whether social media platforms should be regulated by the government is multifaceted, requiring careful consideration of its advantages and disadvantages, along with its broader societal implications. While regulation offers the potential for greater transparency, protection of user data, and safer online interactions, it also poses risks related to censorship and stifling of innovation. As these platforms continue to play an integral role in the fabric of society, it is essential to strike a balanced approach that ensures accountability without compromising the core tenets of freedom and creativity that are at the heart of social media's success.
#
# 🧠 Feedback:
#
# Here’s a detailed critique of your draft, organized by criteria, followed by concrete suggestions and a brief sample of a tightened-up version.
#
# 1. Structure
# • What works:
#   – Clear “Advantages / Disadvantages / Effect on Society / Conclusion” breakdown.
#   – Logical flow from positives to negatives, ending in a synthesis.
# • Where to improve:
#   – The introduction could foreshadow your main argument more assertively (a thesis statement that stakes out your position or the tension you’ll explore).
#   – The “Effect on Society” section overlaps with advantages/disadvantages—consider integrating societal impact into each or renaming it “Broader Implications.”
#   – Use clearer transitions (“Conversely,” “Moreover,” “On the other hand”) to guide readers through your points.
#
# 2. Clarity
# • What works:
#   – Language is mostly straightforward and jargon-free.
#   – Paragraphs stay on topic.
# • Where to improve:
#   – Drop repeated phrases (“government regulation” appears in almost every sentence)—vary with pronouns or synonyms.
#   – Specify what you mean by “regulation.” Are you discussing content-moderation laws, data-privacy statutes, or something else?
#   – Tighten generalities (e.g. “valuable as currency”) by citing a concrete example or statistic.
#
# 3. Strength of Argument
# • What works:
#   – You fairly present both sides, which builds credibility.
#   – You highlight essential trade-offs (accountability vs. censorship; safety vs. innovation).
# • Where to improve:
#   – Lacks evidence. Bolster claims with a concrete case: Germany’s Network Enforcement Act, the EU’s DSA, or China’s social credit implications.
#   – Consider a short “counter-counterargument”: e.g. “Some argue self-regulation can work if platforms adopt best practices. Yet….”
#   – End with a stronger, more nuanced recommendation. Right now the conclusion restates the dilemma but doesn’t guide policy or action.
#
# 4. Writing Style
# • What works:
#   – Professional tone, appropriate for an academic or policy audience.
#   – Smooth sentence structure, few grammatical errors.
# • Where to improve:
#   – Vary sentence length—mix shorter punchy sentences with longer analytical ones to keep reader engagement.
#   – Use active voice more selectively (“Governments can impose…” instead of “there is potential for the establishment…”).
#   – Drop filler phrases (“in recent years,” “in turn,” “on the other hand”) when possible.
#
# —
# Concrete Suggestions
# 1. Introduction & Thesis
#    Revise to set stakes:
#    “As social media reshapes politics, commerce, and culture, governments worldwide face mounting pressure to regulate. This essay argues that—while judicious regulation can curb misinformation and protect data privacy—overreach threatens free expression and innovation. Striking the right balance demands narrowly tailored laws, robust judicial oversight, and platform cooperation.”
#
# 2. Evidence & Examples
#    • After your first advantage, cite a fact: “In 2021, Facebook took down 20 million pieces of hate speech under Germany’s NetzDG.”
#    • In the censorship section, mention a real-world instance: “In Turkey, Twitter shutdowns in 2014 illustrate how content-removal powers can silence political dissent.”
#
# 3. Nuanced Conclusion
#    Instead of “it’s complicated,” offer a roadmap:
#    • “Governments should adopt targeted, transparent rules requiring platforms to publish biannual content-moderation reports.
#    • Independent oversight bodies must review takedown decisions.
#    • A tiered system of penalties—warnings, fines, temporary suspensions—can deter bad actors without sweeping bans.”
#
# Brief Sample Revision of Your Conclusion
# “Ultimately, well-crafted regulation can turn social media from a Wild West of misinformation into a safer, more transparent public square. But only if lawmakers define clear, narrow mandates—focused on data privacy, hate speech, and violent content—and pair them with strong judicial review and platform accountability. By calibrating rules to respect free expression while protecting vulnerable users, policymakers can harness social media’s benefits without silencing dissent or stifling innovation.”
#
# —
# With these changes, your essay will (1) stake out a clear, watchable thesis; (2) ground assertions in real-world data; (3) sharpen transitions; and (4) end by pointing the reader toward specific policy steps rather than restating the problem.
# ✍️ Revised:
#
# I am unable to perform real-time web searches or verify specific recent events or dates. However, I can certainly help refine your essay based on the provided draft and revised critique. Here's a summary of the recommendations and a proposed revision of your introduction and conclusion based on the feedback you've received:
#
# ### Introduction & Thesis Revision:
# **Original Draft:**
# The introduction is clear but lacks a specific thesis statement that captures your stance or explores the tension between regulation and freedom.
#
# **Revised Introduction:**
# "As social media reshapes politics, commerce, and culture, governments worldwide face mounting pressure to regulate. This essay argues that—while judicious regulation can curb misinformation and protect data privacy—overreach threatens free expression and innovation. Striking the right balance demands narrowly tailored laws, robust judicial oversight, and platform cooperation."
#
# ### Evidence & Examples:
# In your essay, consider integrating concrete examples for stronger argumentation:
#
# - **Advantages Section:** After discussing increased accountability, you could add, "In 2021, Facebook took down 20 million pieces of hate speech under Germany’s Network Enforcement Act, illustrating the potential for regulation to curb harmful content."
#
# - **Disadvantages Section:** To illustrate the risks of government control, mention, "In Turkey, Twitter shutdowns in 2014 demonstrate how content-removal powers can suppress political dissent."
#
# ### Nuanced Conclusion:
# **Original Draft Conclusion:**
# The conclusion restates the dilemma without offering a clear direction for action.
#
# **Revised Conclusion:**
# "Ultimately, well-crafted regulation can transform social media from a chaotic information landscape into a safer, more transparent public square. However, it is crucial for lawmakers to define clear, narrow mandates—focused on data privacy, hate speech, and violent content—and pair these with robust judicial review and platform accountability. By calibrating rules to respect free expression while safeguarding vulnerable users, policymakers can harness the benefits of social media without stifling dissent or innovation. Governments should adopt targeted rules requiring platforms to publish regular content moderation reports and create independent oversight bodies to review takedown decisions. Employing a tiered penalty system can deter violations without resorting to sweeping bans."
#
# By implementing these changes, your essay should present a more balanced, well-supported argument while guiding the reader toward specific policy actions.

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils import show_output

essay_prompt = "Should social media platforms be regulated by the government?"

show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">**Title: Should Social Media Platforms Be Regulated by the Government?**
#
# In recent years, social media platforms have become central to communication, information dissemination, and social interaction worldwide. The rise in their influence has sparked an ongoing debate regarding whether these platforms should be regulated by the government. While there are compelling arguments on both sides, understanding the potential advantages and disadvantages, as well as the broader effects on society, is crucial to forming a well-rounded perspective.
#
# **Advantages of Government Regulation**
#
# One of the primary advantages of government regulation of social media platforms is the promise of increased accountability and transparency. With regulation, there is potential for the establishment of clear guidelines and standards that platforms must adhere to. This can help combat misinformation and fake news by holding platforms accountable for the content they allow to circulate. Furthermore, government regulation can ensure that users' data is protected, establishing legal frameworks to prevent unauthorized data collection and usage, which is critical in an age where personal data is as valuable as currency.
#
# Additionally, regulation can aid in the protection of vulnerable groups from harmful and abusive content. By implementing stricter controls and monitoring systems, governments can ensure that platforms actively work to prevent hate speech, cyberbullying, and other harmful behaviors, creating safer online environments for all users. This, in turn, can contribute to healthier digital social interactions and greater trust in these digital platforms.
#
# **Disadvantages of Government Regulation**
#
# Despite the potential benefits, there are significant concerns regarding government regulation of social media platforms. One major disadvantage is the risk of censorship and infringement on free speech. Government involvement in regulating content may lead to the suppression of dissenting opinions and the curtailment of freedom of expression, depending on how regulation is implemented. This can be particularly concerning in countries where governments have a history of oppressive measures against political opponents and journalists.
#
# Moreover, the potential for regulatory overreach is significant. Given the complexity and rapid evolution of technology and digital communication, there is a risk that government regulations might not only be slow to adapt but also stifle innovation. Platforms may be burdened with compliance requirements, reducing their agility and capacity to innovate and respond to the needs of their users dynamically.
#
# **Effect on Society**
#
# The regulation of social media platforms has a profound impact on society, both in its promise to mitigate harm and the potential to alter the fabric of free discourse. On one hand, effective regulation can enhance civic discourse by curbing the spread of misinformation and creating spaces where healthy debate can thrive. On the other hand, if not carefully crafted, regulation can hinder the very discourse it aims to protect, leading to homogenization of viewpoints and diminished public dialogue.
#
# Social media platforms, in their current unregulated or self-regulated states, have already shown the capability to dramatically sway public opinion and influence social and political movements. The introduction of government regulation, therefore, places further emphasis on the responsibility of both governments and platform providers to balance the need for security with the preservation of democratic freedoms.
#
# **Conclusion**
#
# The question of whether social media platforms should be regulated by the government is multifaceted, requiring careful consideration of its advantages and disadvantages, along with its broader societal implications. While regulation offers the potential for greater transparency, protection of user data, and safer online interactions, it also poses risks related to censorship and stifling of innovation. As these platforms continue to play an integral role in the fabric of society, it is essential to strike a balanced approach that ensures accountability without compromising the core tenets of freedom and creativity that are at the heart of social media's success.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Here’s a detailed critique of your draft, organized by criteria, followed by concrete suggestions and a brief sample of a tightened-up version.
#
# 1. Structure
# • What works:
#   – Clear “Advantages / Disadvantages / Effect on Society / Conclusion” breakdown.
#   – Logical flow from positives to negatives, ending in a synthesis.
# • Where to improve:
#   – The introduction could foreshadow your main argument more assertively (a thesis statement that stakes out your position or the tension you’ll explore).
#   – The “Effect on Society” section overlaps with advantages/disadvantages—consider integrating societal impact into each or renaming it “Broader Implications.”
#   – Use clearer transitions (“Conversely,” “Moreover,” “On the other hand”) to guide readers through your points.
#
# 2. Clarity
# • What works:
#   – Language is mostly straightforward and jargon-free.
#   – Paragraphs stay on topic.
# • Where to improve:
#   – Drop repeated phrases (“government regulation” appears in almost every sentence)—vary with pronouns or synonyms.
#   – Specify what you mean by “regulation.” Are you discussing content-moderation laws, data-privacy statutes, or something else?
#   – Tighten generalities (e.g. “valuable as currency”) by citing a concrete example or statistic.
#
# 3. Strength of Argument
# • What works:
#   – You fairly present both sides, which builds credibility.
#   – You highlight essential trade-offs (accountability vs. censorship; safety vs. innovation).
# • Where to improve:
#   – Lacks evidence. Bolster claims with a concrete case: Germany’s Network Enforcement Act, the EU’s DSA, or China’s social credit implications.
#   – Consider a short “counter-counterargument”: e.g. “Some argue self-regulation can work if platforms adopt best practices. Yet….”
#   – End with a stronger, more nuanced recommendation. Right now the conclusion restates the dilemma but doesn’t guide policy or action.
#
# 4. Writing Style
# • What works:
#   – Professional tone, appropriate for an academic or policy audience.
#   – Smooth sentence structure, few grammatical errors.
# • Where to improve:
#   – Vary sentence length—mix shorter punchy sentences with longer analytical ones to keep reader engagement.
#   – Use active voice more selectively (“Governments can impose…” instead of “there is potential for the establishment…”).
#   – Drop filler phrases (“in recent years,” “in turn,” “on the other hand”) when possible.
#
# —
# Concrete Suggestions
# 1. Introduction & Thesis
#    Revise to set stakes:
#    “As social media reshapes politics, commerce, and culture, governments worldwide face mounting pressure to regulate. This essay argues that—while judicious regulation can curb misinformation and protect data privacy—overreach threatens free expression and innovation. Striking the right balance demands narrowly tailored laws, robust judicial oversight, and platform cooperation.”
#
# 2. Evidence & Examples
#    • After your first advantage, cite a fact: “In 2021, Facebook took down 20 million pieces of hate speech under Germany’s NetzDG.”
#    • In the censorship section, mention a real-world instance: “In Turkey, Twitter shutdowns in 2014 illustrate how content-removal powers can silence political dissent.”
#
# 3. Nuanced Conclusion
#    Instead of “it’s complicated,” offer a roadmap:
#    • “Governments should adopt targeted, transparent rules requiring platforms to publish biannual content-moderation reports.
#    • Independent oversight bodies must review takedown decisions.
#    • A tiered system of penalties—warnings, fines, temporary suspensions—can deter bad actors without sweeping bans.”
#
# Brief Sample Revision of Your Conclusion
# “Ultimately, well-crafted regulation can turn social media from a Wild West of misinformation into a safer, more transparent public square. But only if lawmakers define clear, narrow mandates—focused on data privacy, hate speech, and violent content—and pair them with strong judicial review and platform accountability. By calibrating rules to respect free expression while protecting vulnerable users, policymakers can harness social media’s benefits without silencing dissent or stifling innovation.”
#
# —
# With these changes, your essay will (1) stake out a clear, watchable thesis; (2) ground assertions in real-world data; (3) sharpen transitions; and (4) end by pointing the reader toward specific policy steps rather than restating the problem.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">I am unable to perform real-time web searches or verify specific recent events or dates. However, I can certainly help refine your essay based on the provided draft and revised critique. Here's a summary of the recommendations and a proposed revision of your introduction and conclusion based on the feedback you've received:
#
# ### Introduction & Thesis Revision:
# **Original Draft:**
# The introduction is clear but lacks a specific thesis statement that captures your stance or explores the tension between regulation and freedom.
#
# **Revised Introduction:**
# "As social media reshapes politics, commerce, and culture, governments worldwide face mounting pressure to regulate. This essay argues that—while judicious regulation can curb misinformation and protect data privacy—overreach threatens free expression and innovation. Striking the right balance demands narrowly tailored laws, robust judicial oversight, and platform cooperation."
#
# ### Evidence & Examples:
# In your essay, consider integrating concrete examples for stronger argumentation:
#
# - **Advantages Section:** After discussing increased accountability, you could add, "In 2021, Facebook took down 20 million pieces of hate speech under Germany’s Network Enforcement Act, illustrating the potential for regulation to curb harmful content."
#
# - **Disadvantages Section:** To illustrate the risks of government control, mention, "In Turkey, Twitter shutdowns in 2014 demonstrate how content-removal powers can suppress political dissent."
#
# ### Nuanced Conclusion:
# **Original Draft Conclusion:**
# The conclusion restates the dilemma without offering a clear direction for action.
#
# **Revised Conclusion:**
# "Ultimately, well-crafted regulation can transform social media from a chaotic information landscape into a safer, more transparent public square. However, it is crucial for lawmakers to define clear, narrow mandates—focused on data privacy, hate speech, and violent content—and pair these with robust judicial review and platform accountability. By calibrating rules to respect free expression while safeguarding vulnerable users, policymakers can harness the benefits of social media without stifling dissent or innovation. Governments should adopt targeted rules requiring platforms to publish regular content moderation reports and create independent oversight bodies to review takedown decisions. Employing a tiered penalty system can deter violations without resorting to sweeping bans."
#
# By implementing these changes, your essay should present a more balanced, well-supported argument while guiding the reader toward specific policy actions.</pre>
#     </div>

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
