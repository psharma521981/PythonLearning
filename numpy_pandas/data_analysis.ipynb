# %% [markdown]
# **Data Analysis**
# Importent part of data analyss to check the data
#   - check the data
#   - clean the data by removing some of the unnecessary fields
#   - Transform some of the fields for more descriptive meaning

# %%
import numpy as np
import pandas as pd
import os

titanic_train = pd.read_csv("/content/sample_data/titanic.csv")
  #diemnesion of data
#titanic_train.shape
  #data types used in dataset
#titanic_train.dtypes

  #top 15 records
#titanic_train.head(5)
  #describe the dataset
#titanic_train.describe()
  #Sort the data and provide first 15 records
#sorted(titanic_train["Name"])[0:15]

  #get the data for display. top 15 records for cabin
#titanic_train["Cabin"][0:15]
  # describe the column
#titanic_train["Cabin"].describe()

#data cleaning
#del titanic_train["Ticket"]
#del titanic_train["Fare"]
titanic_train.head(5)

#Data transform

#new_survived = pd.Categorical(titanic_train["Survived"])
#new_survived = new_survived.rename_categories(["Died","Survived"])
#new_survived.describe()
#titanic_train.head(5)
#titanic_train["Cabin"].unique()
#char_cabin = titanic_train["Cabin"].astype(str) # Convert data to str
#new_Cabin = np.array([cabin[0] for cabin in char_cabin]) # Take first letter
#new_Cabin = pd.Categorical(new_Cabin)
#new_Cabin .describe()
#titanic_train["Age"].describe()
dummy_vector = pd.Series([1,None,3,None,7,8]) #null value
dummy_vector.isnull()
missing = np.where(titanic_train["Age"].isnull() == True) #finding missing value
missing

#titanic_train.hist(column='Age',    # Column to plot
#                   figsize=(9,6),   # Plot size
#                   bins=20)         # Number of histogram bins
new_age_var = np.where(titanic_train["Age"].isnull(), # Logical check
                       28,                       # Value if check is true
                       titanic_train["Age"])     # Value if check is false

titanic_train["Age"] = new_age_var

titanic_train["Age"].describe()
#titanic_train.hist(column='Age',    # Column to plot
#                   figsize=(9,6),   # Plot size
#                   bins=20)
titanic_train["Fare"].plot(kind="box",
                           figsize=(9,9))

index = np.where(titanic_train["Fare"] == max(titanic_train["Fare"]) )

titanic_train.loc[index]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
